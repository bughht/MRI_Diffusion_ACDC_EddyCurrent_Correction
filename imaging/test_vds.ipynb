# %% [markdown]
# # Unit test for VDS implementation

# %%
import numpy as np
import matplotlib.pyplot as plt
from pSeq.pSeq_Spiral import pSeq_Spiral

vds_gen = pSeq_Spiral()
smax = 15000
gmax = 4.0
T = 0.000004
N = 10
Fcoeff = [24.0]
rmax = 5.0

k, g, s, t, r, theta = vds_gen.calc_vds(smax, gmax, T, N, Fcoeff, rmax)

plt.figure()
plt.plot(np.real(k), np.imag(k))
plt.title('Variable Density Spiral k-space trajectory')
plt.show()
