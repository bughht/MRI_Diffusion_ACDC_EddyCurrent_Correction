# %% [markdown]
# # Multi-shot Spiral Diffusion Imaging Sequence
# Based on pSeq framework.

# %%
import pypulseq as pp
import numpy as np
from pSeq.pSeq_Spiral import pSeq_Spiral

seq = pp.Sequence()
spiral_gen = pSeq_Spiral()
# Add sequence blocks... (Mockup based on EPI diffusion)
print("Multi-shot Spiral Diffusion Sequence initialized.")
